# %% [markdown]
# # Trabalho Prático | Tecnologias para desenv. de soluções de big data
#
# ### Objetivos da prática
#
# * Descrever como ler um arquivo CSV usando a biblioteca Pandas (Python);
# * Descrever como criar um subconjunto de dados a partir de um conjunto existente usando a biblioteca Pandas (Python);
# * Descrever como configurar o número máximo de linhas a serem exibidas na visualização de um conjunto de dados usando a biblioteca Pandas (Python);
# * Descrever como exibir as primeiras e últimas “N” linhas de um conjunto de dados usando a biblioteca Pandas (Python); Descrever como exibir informações gerais sobre as colunas, linhas e dados de um conjunto de dados usando a biblioteca Pandas (Python);
#
# ### Contextualização
#
# Como Analista de Dados, você recebeu, em um novo projeto, um conjunto de dados.
# Sua principal tarefa é tratar os dados desse conjunto a fim de que possam ser
# utilizados para a descoberta de conhecimento através de sua posterior análise e
# interpretação. Para tal tarefa, você deverá utilizar a linguagem Python e a biblioteca
# Pandas. O passo-a-passo de todo o processo de tratamento dos dados é apresentado a
# seguir, no roteiro de prática.

# %% [markdown]
# ## Procedimentos

# %% [markdown]
# 1. Para essa atividade você deverá, obrigatoriamente, utilizar o conjunto de dados (fornecido anteriormente) composto pelas colunas ID;Duration;Date;Pulse;Maxpulse;Calories ;
#
# 2. Crie um novo arquivo/script;

# %%
data_string = """
ID;Duration;Date;Pulse;Maxpulse;Calories
0;60;'2020/12/01';110;130;4091
1;60;'2020/12/02';117;145;4790
2;60;'2020/12/03';103;135;3400
3;45;'2020/12/04';109;175;2824
4;45;'2020/12/05';117;148;4060
5;60;'2020/12/06';102;127;3000
6;60;'2020/12/07';110;136;3740
7;450;'2020/12/08';104;134;2533
8;30;'2020/12/09';109;133;1951
9;60;'2020/12/10';98;124;2690
10;60;'2020/12/11';103;147;3293
11;60;'2020/12/12';100;120;2507
12;60;'2020/12/12';100;120;2507
13;60;'2020/12/13';106;128;3453
14;60;'2020/12/14';104;132;3793
15;60;'2020/12/15';98;123;2750
16;60;'2020/12/16';98;120;2152
17;60;'2020/12/17';100;120;3000
18;45;'2020/12/18';90;112;NaN
19;60;'2020/12/19';103;123;3230
20;45;'2020/12/20';97;125;2430
21;60;'2020/12/21';108;131;3642
22;45;NaN;100;119;2820
23;60;'2020/12/23';130;101;3000
24;45;'2020/12/24';105;132;2460
25;60;'2020/12/25';102;126;3345
26;60;20201226;100;120;2500
27;60;'2020/12/27';92;118;2410
28;60;'2020/12/28';103;132;NaN
29;60;'2020/12/29';100;132;2800
30;60;'2020/12/30';102;129;3803
31;60;'2020/12/31';92;115;2430
"""

# %% [markdown]
# 3. Leia o conteúdo do CSV fornecido, atentando-se para a necessidade ou não de incluir parâmetros adicionais como os relativos ao separador dos dados, a engine e o enconding;
#
# 4. Atribua os dados lidos a uma variável;

# %%
import pandas as pd

# CRIAÇÃO DO ARQUIVO CSV
with open('./datasets/data.csv', 'w', encoding='utf-8') as file:
    file.write(data_string)

# FAZ A LEITURA DOS DADOS DE ./datasets/data.csv
data_original = pd.read_csv('./datasets/data.csv', sep=';', engine='python', encoding='utf-8')

# %% [markdown]
# 5. Verifique se os dados foram importados adequadamente:<br>

# %% [markdown]
# a. Imprima as informações gerais sobre o conjunto de dados;<br>

# %%
print("\n--- Informações Gerais do Conjunto de dados ---")
data_original.info()
# Out:
# --- Informações Gerais do Conjunto de dados ---
# <class 'pandas.DataFrame'>
# RangeIndex: 32 entries, 0 to 31
# Data columns (total 6 columns):
#  #   Column    Non-Null Count  Dtype
# ---  ------    --------------  -----
#  0   ID        32 non-null     int64
#  1   Duration  32 non-null     int64
#  2   Date      31 non-null     str
#  3   Pulse     32 non-null     int64
#  4   Maxpulse  32 non-null     int64
#  5   Calories  30 non-null     float64
# dtypes: float64(1), int64(4), str(1)
# memory usage: 1.6 KB

# %% [markdown]
# b. Imprima as primeiras e últimas N linhas do arquivo.

# %%
print("\n--- Primeiras 10 linhas ---")
print(data_original.head(10))

print("\n--- Últimas 10 linhas ---")
print(data_original.tail(10))
# Out:
# --- Primeiras 10 linhas ---
#    ID  Duration          Date  Pulse  Maxpulse  Calories
# 0   0        60  '2020/12/01'    110       130    4091.0
# 1   1        60  '2020/12/02'    117       145    4790.0
# 2   2        60  '2020/12/03'    103       135    3400.0
# 3   3        45  '2020/12/04'    109       175    2824.0
# 4   4        45  '2020/12/05'    117       148    4060.0
# 5   5        60  '2020/12/06'    102       127    3000.0
# 6   6        60  '2020/12/07'    110       136    3740.0
# 7   7       450  '2020/12/08'    104       134    2533.0
# 8   8        30  '2020/12/09'    109       133    1951.0
# 9   9        60  '2020/12/10'     98       124    2690.0
#
# --- Últimas 10 linhas ---
#     ID  Duration          Date  Pulse  Maxpulse  Calories
# 22  22        45           NaN    100       119    2820.0
# 23  23        60  '2020/12/23'    130       101    3000.0
# 24  24        45  '2020/12/24'    105       132    2460.0
# ...

# %% [markdown]
# 6. Crie uma nova variável e atribua a ela uma cópia do conjunto de dados original (variável criada no passo 4);

# %%
data_copy = data_original.copy()

# %% [markdown]
# 7. Nessa nova variável, contendo uma cópia dos dados:<br>

# %% [markdown]
# a. Substitua todos os valores nulos da coluna ‘Calories’ por 0;<br>

# %%
data_copy['Calories'] = data_copy['Calories'].fillna(0)

# %% [markdown]
# b. Imprima o conjunto de dados para verificar se a mudança acima foi aplicada com sucesso;<br>

# %%
print("\n--- Verificação Coluna Calories (nulos substituídos por 0) ---")
print(data_copy.to_string())
# Out:
# --- Verificação Coluna Calories (nulos substituídos por 0) ---
#     ID  Duration          Date  Pulse  Maxpulse  Calories
# 0    0        60  '2020/12/01'    110       130    4091.0
# 1    1        60  '2020/12/02'    117       145    4790.0
# 2    2        60  '2020/12/03'    103       135    3400.0
# 3    3        45  '2020/12/04'    109       175    2824.0
# 4    4        45  '2020/12/05'    117       148    4060.0
# 5    5        60  '2020/12/06'    102       127    3000.0
# 6    6        60  '2020/12/07'    110       136    3740.0
# 7    7       450  '2020/12/08'    104       134    2533.0
# 8    8        30  '2020/12/09'    109       133    1951.0
# 9    9        60  '2020/12/10'     98       124    2690.0
# 10  10        60  '2020/12/11'    103       147    3293.0
# 11  11        60  '2020/12/12'    100       120    2507.0
# 12  12        60  '2020/12/12'    100       120    2507.0
# 13  13        60  '2020/12/13'    106       128    3453.0
# ...

# %% [markdown]
# 8. Ainda na nova variável:<br>

# %% [markdown]
# a. Substitua os valores nulos da coluna ‘Date’ por ‘1900/01/01’;<br>

# %%
data_copy['Date'] = data_copy['Date'].fillna("'1900/01/01'")

# %% [markdown]
# b. Imprima o conjunto de dados e confira se a mudança foi aplicada com sucesso;<br>

# %%
print("\n--- Verificação Coluna Date (nulos substituídos) ---")
print(data_copy.to_string())
# Out:
# --- Verificação Coluna Date (nulos substituídos) ---
#     ID  Duration          Date  Pulse  Maxpulse  Calories
# 0    0        60  '2020/12/01'    110       130    4091.0
# 1    1        60  '2020/12/02'    117       145    4790.0
# 2    2        60  '2020/12/03'    103       135    3400.0
# 3    3        45  '2020/12/04'    109       175    2824.0
# 4    4        45  '2020/12/05'    117       148    4060.0
# 5    5        60  '2020/12/06'    102       127    3000.0
# 6    6        60  '2020/12/07'    110       136    3740.0
# 7    7       450  '2020/12/08'    104       134    2533.0
# 8    8        30  '2020/12/09'    109       133    1951.0
# 9    9        60  '2020/12/10'     98       124    2690.0
# 10  10        60  '2020/12/11'    103       147    3293.0
# 11  11        60  '2020/12/12'    100       120    2507.0
# 12  12        60  '2020/12/12'    100       120    2507.0
# 13  13        60  '2020/12/13'    106       128    3453.0
# ...

# %% [markdown]
# c. Transforme os dados da coluna ‘Date’ em datetime usando o método ‘to_datetime’;<br>

# %%
data_copy['Date'] = pd.to_datetime(data_copy['Date'])
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[152], line 1
# ----> 1 data_copy['Date'] = pd.to_datetime(data_copy['Date'])
#
# File ~/Documents/Faculdade/UNESA - Desenvolvimento Full Stack/5. Mundo 5 (5 periodo)/5. Tecnologias Para Desenv. de Solucoes de Big Data/Trabalho/env/lib/python3.14/site-packages/pandas/core/tools/datetimes.py:1040, in to_datetime(arg, errors, dayfirst, yearfirst, utc, format, exact, unit, origin, cache)
#    1038         result = arg.map(cache_array)
#    1039     else:
# -> 1040         values = convert_listlike(arg._values, format)
#    1041         result = arg._constructor(values, index=arg.index, name=arg.name)
#    1042 elif isinstance(arg, (ABCDataFrame, abc.MutableMapping)):
#
# ...

# %% [markdown]
# 9. Tendo seguido todas as instruções anteriores, ao executar o passo anterior você deverá ter encontrado um erro informando que o valor ‘1900/01/01’ não corresponde ao formato ‘%Y/%m/%d’. Para resolver esse problema:<br>

# %% [markdown]
# a. Substitua, na coluna ‘Date’, o valor ‘1900/01/01’ por ‘NaN’;<br>

# %%
import numpy as np

data_copy['Date'] = data_copy['Date'].replace("'1900/01/01'", np.nan)

# %% [markdown]
# b. Utilizando o método ‘to_datetime’, repita o passo de transformação dos dados da coluna ‘Date’ para datetime;<br>

# %%
data_copy['Date'] = pd.to_datetime(data_copy['Date'])
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[154], line 1
# ----> 1 data_copy['Date'] = pd.to_datetime(data_copy['Date'])
#
# File ~/Documents/Faculdade/UNESA - Desenvolvimento Full Stack/5. Mundo 5 (5 periodo)/5. Tecnologias Para Desenv. de Solucoes de Big Data/Trabalho/env/lib/python3.14/site-packages/pandas/core/tools/datetimes.py:1040, in to_datetime(arg, errors, dayfirst, yearfirst, utc, format, exact, unit, origin, cache)
#    1038         result = arg.map(cache_array)
#    1039     else:
# -> 1040         values = convert_listlike(arg._values, format)
#    1041         result = arg._constructor(values, index=arg.index, name=arg.name)
#    1042 elif isinstance(arg, (ABCDataFrame, abc.MutableMapping)):
#
# ...

# %% [markdown]
# c. Imprima o conjunto de dados para verificar se as mudanças acima foram aplicadas com sucesso;<br>

# %%
print('\n|||||||||||||||||||||||||||||')
print('COM ERRO NO FORMATO DA DATA NO ID 26')
print(data_copy.to_string())
# Out:
# |||||||||||||||||||||||||||||
# COM ERRO NO FORMATO DA DATA NO ID 26
#     ID  Duration          Date  Pulse  Maxpulse  Calories
# 0    0        60  '2020/12/01'    110       130    4091.0
# 1    1        60  '2020/12/02'    117       145    4790.0
# 2    2        60  '2020/12/03'    103       135    3400.0
# 3    3        45  '2020/12/04'    109       175    2824.0
# 4    4        45  '2020/12/05'    117       148    4060.0
# 5    5        60  '2020/12/06'    102       127    3000.0
# 6    6        60  '2020/12/07'    110       136    3740.0
# 7    7       450  '2020/12/08'    104       134    2533.0
# 8    8        30  '2020/12/09'    109       133    1951.0
# 9    9        60  '2020/12/10'     98       124    2690.0
# 10  10        60  '2020/12/11'    103       147    3293.0
# 11  11        60  '2020/12/12'    100       120    2507.0
# 12  12        60  '2020/12/12'    100       120    2507.0
# 13  13        60  '2020/12/13'    106       128    3453.0
# ...

# %% [markdown]
# 10. Nesse ponto, você deverá ter esbarrado em outro erro, informando agora que o valor "20201226" não corresponde ao formato "'%Y/%m/%d'" . Você precisará, agora, na coluna ‘Date”, transformar especificamente esse valor, atualmente uma string, para o formato datetime. Para isso você deverá combinar os métodos ‘replace’ e ‘to_datetime’;

# %%
data_copy['Date'] = data_copy['Date'].replace("20201226", "'2020/12/26'")

# %% [markdown]
# 11. Após o passo anterior, execute novamente a transformação de todos os dados da coluna ‘Date’ para o formato datetime (usando o to_datetime). Imprima o conjunto de dados atual para verificar se todas as transformações foram executadas com sucesso;

# %%
data_copy['Date'] = data_copy['Date'].str.replace("'", "")
data_copy['Date'] = pd.to_datetime(data_copy['Date'], format='%Y/%m/%d')

print('\n|||||||||||||||||||||||||||||')
print('ERROS CORRIGIDOS')
print(data_copy.to_string())
# Out:
# |||||||||||||||||||||||||||||
# ERROS CORRIGIDOS
#     ID  Duration       Date  Pulse  Maxpulse  Calories
# 0    0        60 2020-12-01    110       130    4091.0
# 1    1        60 2020-12-02    117       145    4790.0
# 2    2        60 2020-12-03    103       135    3400.0
# 3    3        45 2020-12-04    109       175    2824.0
# 4    4        45 2020-12-05    117       148    4060.0
# 5    5        60 2020-12-06    102       127    3000.0
# 6    6        60 2020-12-07    110       136    3740.0
# 7    7       450 2020-12-08    104       134    2533.0
# 8    8        30 2020-12-09    109       133    1951.0
# 9    9        60 2020-12-10     98       124    2690.0
# 10  10        60 2020-12-11    103       147    3293.0
# 11  11        60 2020-12-12    100       120    2507.0
# 12  12        60 2020-12-12    100       120    2507.0
# 13  13        60 2020-12-13    106       128    3453.0
# 14  14        60 2020-12-14    104       132    3793.0
# ...

# %% [markdown]
# 12. Por fim, remova os registros contendo valores nulos. Nesse ponto, apenas a coluna ‘Date’ possui um registro que atende a essa premissa (linha 22). Logo, utilize-a como base para realizar a transformação solicitada;

# %%
data_copy.dropna(subset=['Date'], inplace=True)

# %% [markdown]
# 13. Imprima o dataframe e verifique se todas as transformações foram executadas conforme solicitado nos passos anteriores.

# %%
print(data_copy.to_string())
# Out:
#     ID  Duration       Date  Pulse  Maxpulse  Calories
# 0    0        60 2020-12-01    110       130    4091.0
# 1    1        60 2020-12-02    117       145    4790.0
# 2    2        60 2020-12-03    103       135    3400.0
# 3    3        45 2020-12-04    109       175    2824.0
# 4    4        45 2020-12-05    117       148    4060.0
# 5    5        60 2020-12-06    102       127    3000.0
# 6    6        60 2020-12-07    110       136    3740.0
# 7    7       450 2020-12-08    104       134    2533.0
# 8    8        30 2020-12-09    109       133    1951.0
# 9    9        60 2020-12-10     98       124    2690.0
# 10  10        60 2020-12-11    103       147    3293.0
# 11  11        60 2020-12-12    100       120    2507.0
# 12  12        60 2020-12-12    100       120    2507.0
# 13  13        60 2020-12-13    106       128    3453.0
# 14  14        60 2020-12-14    104       132    3793.0
# 15  15        60 2020-12-15     98       123    2750.0
# ...
